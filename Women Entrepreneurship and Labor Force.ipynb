# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv('Women Entrepreneurship and Labor Force.csv',sep= ";")

# %%
df=pd.DataFrame(data)

# %%
print(df)
# Out:
#     No                 Country Level of development European Union Membership  \
# 0    4                 Austria            Developed                    Member
# 1    6                 Belgium            Developed                    Member
# 2   17                 Estonia            Developed                    Member
# 3   18                 Finland            Developed                    Member
# 4   19                  France            Developed                    Member
# 5   20                 Germany            Developed                    Member
# 6   22                  Greece            Developed                    Member
# 7   28                 Ireland            Developed                    Member
# 8   30                   Italy            Developed                    Member
# 9   34                  Latvia            Developed                    Member
# 10  35               Lithuania            Developed                    Member
# ...

# %%
print(data)
# Out:
#     No                 Country Level of development European Union Membership  \
# 0    4                 Austria            Developed                    Member
# 1    6                 Belgium            Developed                    Member
# 2   17                 Estonia            Developed                    Member
# 3   18                 Finland            Developed                    Member
# 4   19                  France            Developed                    Member
# 5   20                 Germany            Developed                    Member
# 6   22                  Greece            Developed                    Member
# 7   28                 Ireland            Developed                    Member
# 8   30                   Italy            Developed                    Member
# 9   34                  Latvia            Developed                    Member
# 10  35               Lithuania            Developed                    Member
# ...

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of     No                 Country Level of development European Union Membership  \
# 0    4                 Austria            Developed                    Member
# 1    6                 Belgium            Developed                    Member
# 2   17                 Estonia            Developed                    Member
# 3   18                 Finland            Developed                    Member
# 4   19                  France            Developed                    Member
# 5   20                 Germany            Developed                    Member
# 6   22                  Greece            Developed                    Member
# 7   28                 Ireland            Developed                    Member
# 8   30                   Italy            Developed                    Member
# 9   34                  Latvia            Developed                    Member
# 10  35               Lithuania            Developed                    Member
# ...

# %%
print(df.tail)
# Out:
# <bound method NDFrame.tail of     No                 Country Level of development European Union Membership  \
# 0    4                 Austria            Developed                    Member
# 1    6                 Belgium            Developed                    Member
# 2   17                 Estonia            Developed                    Member
# 3   18                 Finland            Developed                    Member
# 4   19                  France            Developed                    Member
# 5   20                 Germany            Developed                    Member
# 6   22                  Greece            Developed                    Member
# 7   28                 Ireland            Developed                    Member
# 8   30                   Italy            Developed                    Member
# 9   34                  Latvia            Developed                    Member
# 10  35               Lithuania            Developed                    Member
# ...

# %%
print(df.shape)
# Out:
# (51, 9)

# %%
print(df.describe())
# Out:
#               No  Women Entrepreneurship Index  Entrepreneurship Index  \
# count  51.000000                     51.000000               51.000000
# mean   29.980392                     47.835294               47.241176
# std    18.017203                     14.268480               16.193149
# min     1.000000                     25.300000               24.800000
# 25%    14.500000                     36.350000               31.900000
# 50%    30.000000                     44.500000               42.700000
# 75%    45.500000                     59.150000               65.400000
# max    60.000000                     74.800000               77.600000
#
#        Inflation rate  Female Labor Force Participation Rate
# count       51.000000                              51.000000
# mean         2.587647                              58.481765
# std          5.380639                              13.864567
# min         -2.250000                              13.000000
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 9 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   No                                     51 non-null     int64
#  1   Country                                51 non-null     object
#  2   Level of development                   51 non-null     object
#  3   European Union Membership              51 non-null     object
#  4   Currency                               51 non-null     object
#  5   Women Entrepreneurship Index           51 non-null     float64
#  6   Entrepreneurship Index                 51 non-null     float64
#  7   Inflation rate                         51 non-null     float64
#  8   Female Labor Force Participation Rate  51 non-null     float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 3.7+ KB
# None

# %%
print(df.isnull())
# Out:
#        No  Country  Level of development  European Union Membership  Currency  \
# 0   False    False                 False                      False     False
# 1   False    False                 False                      False     False
# 2   False    False                 False                      False     False
# 3   False    False                 False                      False     False
# 4   False    False                 False                      False     False
# 5   False    False                 False                      False     False
# 6   False    False                 False                      False     False
# 7   False    False                 False                      False     False
# 8   False    False                 False                      False     False
# 9   False    False                 False                      False     False
# 10  False    False                 False                      False     False
# ...

# %%
print(df.columns)
# Out:
# Index(['No', 'Country', 'Level of development', 'European Union Membership',
#        'Currency', 'Women Entrepreneurship Index', 'Entrepreneurship Index',
#        'Inflation rate', 'Female Labor Force Participation Rate'],
#       dtype='object')

# %%
m1=df['Women Entrepreneurship Index'].mean()

# %%
print(m1)
# Out:
# 47.835294117647045

# %%
m2=df['Entrepreneurship Index'].mean()

# %%
print(m2)
# Out:
# 47.241176470588215

# %%
prepared_data=df

# %%
print(prepared_data)
# Out:
#     No                 Country Level of development European Union Membership  \
# 0    4                 Austria            Developed                    Member
# 1    6                 Belgium            Developed                    Member
# 2   17                 Estonia            Developed                    Member
# 3   18                 Finland            Developed                    Member
# 4   19                  France            Developed                    Member
# 5   20                 Germany            Developed                    Member
# 6   22                  Greece            Developed                    Member
# 7   28                 Ireland            Developed                    Member
# 8   30                   Italy            Developed                    Member
# 9   34                  Latvia            Developed                    Member
# 10  35               Lithuania            Developed                    Member
# ...

# %%
print(prepared_data.corr())
# Out:
#                                              No  Women Entrepreneurship Index  \
# No                                     1.000000                      0.107324
# Women Entrepreneurship Index           0.107324                      1.000000
# Entrepreneurship Index                 0.121687                      0.914580
# Inflation rate                        -0.136945                     -0.455532
# Female Labor Force Participation Rate -0.077828                      0.441372
#
#                                        Entrepreneurship Index  Inflation rate  \
# No                                                   0.121687       -0.136945
# Women Entrepreneurship Index                         0.914580       -0.455532
# Entrepreneurship Index                               1.000000       -0.395370
# Inflation rate                                      -0.395370        1.000000
# Female Labor Force Participation Rate                0.334170       -0.139802
#
# ...

# %%
print(sns.pairplot(data=prepared_data))

# %%
print(prepared_data.columns)
# Out:
# Index(['No', 'Country', 'Level of development', 'European Union Membership',
#        'Currency', 'Women Entrepreneurship Index', 'Entrepreneurship Index',
#        'Inflation rate', 'Female Labor Force Participation Rate'],
#       dtype='object')

# %%
print(prepared_data['No'])
# Out:
# 0      4
# 1      6
# 2     17
# 3     18
# 4     19
# 5     20
# 6     22
# 7     28
# 8     30
# 9     34
# 10    35
# 11    39
# 12    50
# 13    51
# 14    53
# 15    12
# 16    13
# 17    24
# 18    44
# 19    54
# 20     3
# 21    25
# 22    32
# 23    40
# 24    49
# 25    55
# 26    56
# 27     1
# 28     2
# 29     7
# 30     8
# 31     9
# 32    10
# 33    11
# 34    14
# 35    15
# 36    16
# 37    21
# 38    26
# 39    31
# 40    36
# 41    37
# 42    38
# 43    42
# 44    43
# 45    47
# 46    48
# 47    57
# 48    58
# 49    59
# 50    60
# Name: No, dtype: int64

# %%
print(prepared_data['Country'])
# Out:
# 0                    Austria
# 1                    Belgium
# 2                    Estonia
# 3                    Finland
# 4                     France
# 5                    Germany
# 6                     Greece
# 7                    Ireland
# 8                      Italy
# 9                     Latvia
# 10                 Lithuania
# 11               Netherlands
# 12                  Slovakia
# 13                  Slovenia
# 14                     Spain
# 15                   Croatia
# 16                   Denmark
# 17                   Hungary
# 18                    Poland
# 19                    Sweden
# 20                 Australia
# 21                   Iceland
# 22                     Japan
# 23                    Norway
# 24                 Singapore
# 25               Switzerland
# 26                    Taiwan
# 27                   Algeria
# 28                 Argentina
# 29                   Bolivia
# 30    Bosnia and Herzegovina
# 31                    Brazil
# ...

# %%
print(prepared_data.plot(kind='line',x='Country',y='No',title='Country vs No'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(prepared_data.columns)
# Out:
# Index(['No', 'Country', 'Level of development', 'European Union Membership',
#        'Currency', 'Women Entrepreneurship Index', 'Entrepreneurship Index',
#        'Inflation rate', 'Female Labor Force Participation Rate'],
#       dtype='object')

# %%
print(prepared_data.plot(kind='scatter',x='Country',y='European Union Membership',title='Country vs European Union Membership'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(prepared_data.plot(kind='hist'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(prepared_data.plot(kind='line',x='Women Entrepreneurship Index',y='Female Labor Force Participation Rate',title='Women Entrepreneurship Index vs Female Labor Force Participation Rate'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(prepared_data.plot(kind='scatter',x='Women Entrepreneurship Index',y='Female Labor Force Participation Rate',title='Women Entrepreneurship Index vs Female Labor Force Participation Rate'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(prepared_data.plot(kind='bar',x='Women Entrepreneurship Index',y='Female Labor Force Participation Rate',title='Women Entrepreneurship Index vs Female Labor Force Participation Rate'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(prepared_data.plot(kind='box',x='Women Entrepreneurship Index',y='Female Labor Force Participation Rate',title='Women Entrepreneurship Index vs Female Labor Force Participation Rate'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(prepared_data.plot(kind='area',x='Women Entrepreneurship Index',y='Female Labor Force Participation Rate',title='Women Entrepreneurship Index vs Female Labor Force Participation Rate'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(prepared_data.columns)
# Out:
# Index(['No', 'Country', 'Level of development', 'European Union Membership',
#        'Currency', 'Women Entrepreneurship Index', 'Entrepreneurship Index',
#        'Inflation rate', 'Female Labor Force Participation Rate'],
#       dtype='object')

# %%
print(prepared_data.plot(kind='hist'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(prepared_data.plot(kind='line',x='Women Entrepreneurship Index',y='Inflation rate',title='Women Entrepreneurship Index vs Inflation rate'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(prepared_data.plot(kind='scatter',x='Women Entrepreneurship Index',y='Inflation rate',title='Women Entrepreneurship Index vs Inflation rate'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(prepared_data.plot(kind='bar',x='Women Entrepreneurship Index',y='Inflation rate',title='Women Entrepreneurship Index vs Inflation rate'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(prepared_data.plot(kind='box',x='Women Entrepreneurship Index',y='Inflation rate',title='Women Entrepreneurship Index vs Inflation rate'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(prepared_data.plot(kind='hist'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
